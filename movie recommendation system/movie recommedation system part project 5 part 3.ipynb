# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel

# %%
df = pd.read_csv('C:\\Users\\DVM\\Desktop\\ai-ml\\movie recommendation system\\movie dataset.csv', low_memory=False)

# %%
df
# Out:
#       id                                        description
# 0      1  Active classic boxers - There's a reason why o...
# 1      2  Active sport boxer briefs - Skinning up Glory ...
# 2      3  Active sport briefs - These superbreathable no...
# 3      4  Alpine guide pants - Skin in, climb ice, switc...
# 4      5  Alpine wind jkt - On high ridges, steep ice an...
# 5      6  Ascensionist jkt - Our most technical soft she...
# 6      7  Atom - A multitasker's cloud nine, the Atom pl...
# 7      8  Print banded betina btm - Our fullest coverage...
# 8      9  Baby micro d-luxe cardigan - Micro D-Luxe is a...
# 9     10  Baby sun bucket hat - This hat goes on when th...
# 10    11  Baby sunshade top - Soft, stretchy polyester f...
# 11    12  Baggies shorts - Even Baggies, our most popula...
# 12    13  Beach bucket - Whenever you're at the junction...
# 13    14  Better sweater jkt - June nights camped out in...
# 14    15  Borderless shorts-11 in. - Go forward where ot...
# 15    16  Borderless shorts-7 in. - One of summertime's ...
# 16    17  Bucket hat - Besides its shade-casting prowess...
# 17    18  Cap 1 bottoms - Spring skiing is as transient ...
# 18    19  Cap 1 boxer briefs - On bivy or belay, the for...
# 19    20  Cap 1 graphic t-shirt - This tee is made from ...
# 20    21  Cap 1 t-shirt - Minimally styled but technical...
# 21    22  Cap 2 t-shirt - This one revels in the sweat j...
# 22    23  Cap 2 zip neck - Designed for wet-then-chill p...
# 23    24  Cap 3 zip neck - Capilene 3 provides excellent...
# 24    25  Cap 4 bottoms - For sufferfests like the Grand...
# 25    26  City by the sea t-shirt - Illustrating the ren...
# 26    27  Compound cargo pants - long - The ultimate do-...
# 27    28  Compound cargo pants - reg - The ultimate do-e...
# 28    29  Continental shorts - Wrinkle-resistant travel ...
# 29    30  Cotton board shorts - A classic in fabric and ...
# ..   ...                                                ...
# 471  471  Baby live simply seal t-shirt - Swim, fish, ha...
# 472  472  Double haul - Sometimes all you need is a sing...
# 473  473  Down sweater - There's much to see 14,000 feet...
# 474  474  Baby synch cardigan - Springtime temperatures ...
# 475  475  Baby synch vest - A baby's bouldering circuit ...
# 476  476  Baby tag you're it t-shirt - It's not fair: Th...
# 477  477  L/s runshade top - Power pasta feed, one last ...
# 478  478  L/s sol patrol shirt - Two-week boat trips in ...
# 479  479  Bimini cap - South of Kanab, temperatures take...
# 480  480  Borderless messenger shorts - Pair these light...
# 481  481  Duck pants - reg - Essential wear for splittin...
# 482  482  Duck pants - short - Essential wear for splitt...
# 483  483  Duck shorts - Sometimes life requires a welder...
# 484  484  Borderless trek pants - The Ruby Crest trail r...
# 485  485  Borderless trek zip-off pants - Made for techn...
# 486  486  Half mass - Sized for riding a bike and finely...
# 487  487  Cap 1 crew - When it comes to moisture, this l...
# 488  488  Cap 1 graphic crew - The choice for rest days ...
# 489  489  Fitz roy study t-shirt - When unveiled, the Fi...
# 490  490  Flyfishing the athabasca poster - Patrik Ondru...
# 491  491  Flying fish 2 t-shirt - Life's more colorful w...
# 492  492  Freedom to roam t-shirt - Global warming and h...
# 493  493  '73 logo t-shirt - Patagonia's timeless '73 Lo...
# 494  494  Active boxer briefs - A no-fuss travel compani...
# 495  495  Active briefs - These featherweight, quick-wic...
# 496  496  Cap 2 bottoms - Cut loose from the maddening c...
# 497  497  Cap 2 crew - This crew takes the edge off fick...
# 498  498  All-time shell - No need to use that morning T...
# 499  499  All-wear cargo shorts - All-Wear Cargo Shorts ...
# 500  500  All-wear shorts - Time to simplify? Our All-We...
#
# [501 rows x 2 columns]

# %%
tf = TfidfVectorizer(analyzer='word', ngram_range=(1, 3), min_df=0, stop_words='english')
tfidf_matrix = tf.fit_transform(df['description'])

# %%
cosine_similarities = linear_kernel(tfidf_matrix, tfidf_matrix)

# %%
results = {}
for idx, row in df.iterrows():
    similar_indices = cosine_similarities[idx].argsort()[:-100:-1]
    similar_items = [(cosine_similarities[idx][i], df['id'][i]) for i in similar_indices]

    results[row['id']] = similar_items[1:]

# %%
def item(id):
    return df.loc[df['id'] == id]['description'].tolist()[0].split(' - ')[0]

# %%
def recommend(item_id, num):
    print("Recommending " + str(num) + " products similar to " + item(item_id) + "...")
    print("-------")
    recs = results[item_id][:num]
    for rec in recs:
        print("Recommended: " + item(rec[1]) + " (score:" + str(rec[0]) + ")")

# %%
recommend(item_id=11, num=5)
# Out:
# Recommending 5 products similar to Baby sunshade top...
# -------
# Recommended: Sunshade hoody (score:0.2132085763125927)
# Recommended: Baby baggies apron dress (score:0.10971683689776852)
# Recommended: Runshade t-shirt (score:0.0998507310276347)
# Recommended: Runshade t-shirt (score:0.09525106564199565)
# Recommended: Runshade top (score:0.08505198909115931)
